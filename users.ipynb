# %%
import json
import ast
import re
import gzip
import pandas as pd

# %%
row = []  # creo una lista vacia para ir guardando lo que recorre el bucle for

# creo un buble para recorrer el dataset
for i in gzip.open("users_items.json.gz"):
    # leo cada linea y la guardo en la lista row
    row.append(ast.literal_eval(i.decode("utf-8")))

# Creo el dataframe a partir de la lista
usuarios = pd.DataFrame(row)
usuarios

# %%
usuarios = pd.json_normalize(row, record_path=['items'], meta=[
                             'steam_id', 'items_count', 'user_id', 'user_url'])
usuarios
# Out:
#         item_id                      item_name  playtime_forever  \
# 0            10                 Counter-Strike                 6
# 1            20          Team Fortress Classic                 0
# 2            30                  Day of Defeat                 7
# 3            40             Deathmatch Classic                 0
# 4            50      Half-Life: Opposing Force                 0
# ...         ...                            ...               ...
# 5153204  346330                   BrainBread 2                 0
# 5153205  373330                    All Is Dust                 0
# 5153206  388490  One Way To Die: Steam Edition                 3
# 5153207  521570          You Have 10 Seconds 2                 4
# 5153208  519140                     Minds Eyes                 3
#
#          playtime_2weeks           steam_id items_count            user_id  \
# 0                      0  76561197970982479         277  76561197970982479
# ...

# %%
duplicados = usuarios.loc[usuarios.duplicated()]
duplicados
# Out:
#         item_id                         item_name  playtime_forever  \
# 164294       20             Team Fortress Classic                 5
# 164295       50         Half-Life: Opposing Force                 0
# 164296       70                         Half-Life                 0
# 164297      130             Half-Life: Blue Shift                 0
# 164298      220                       Half-Life 2               198
# ...         ...                               ...               ...
# 4898223  213670  South Park™: The Stick of Truth™               725
# 4898224  221910               The Stanley Parable                53
# 4898225  261030      The Walking Dead: Season Two               253
# 4898226  273110     Counter-Strike Nexon: Zombies                 0
# 4898227     730  Counter-Strike: Global Offensive                 0
#
#          playtime_2weeks           steam_id items_count            user_id  \
# ...

# %%
usuarios_corregido = usuarios.drop_duplicates(keep='first')
usuarios_corregido
# Out:
#         item_id                      item_name  playtime_forever  \
# 0            10                 Counter-Strike                 6
# 1            20          Team Fortress Classic                 0
# 2            30                  Day of Defeat                 7
# 3            40             Deathmatch Classic                 0
# 4            50      Half-Life: Opposing Force                 0
# ...         ...                            ...               ...
# 5153204  346330                   BrainBread 2                 0
# 5153205  373330                    All Is Dust                 0
# 5153206  388490  One Way To Die: Steam Edition                 3
# 5153207  521570          You Have 10 Seconds 2                 4
# 5153208  519140                     Minds Eyes                 3
#
#          playtime_2weeks           steam_id items_count            user_id  \
# 0                      0  76561197970982479         277  76561197970982479
# ...

# %%
guardar = 'user_limpio.csv'
usuarios_corregido.to_csv(guardar, index=False, encoding='utf-8')

# %%
# Ruta del archivo Excel
archivo_excel = "df_reviews.xlsx"

# Leer el archivo Excel y guardarlo en una variable
datos = pd.read_excel(archivo_excel)

# Imprimir los datos leídos
print(datos)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# c:\Users\Usuario\Dropbox\Programación\PI MLOps - STEAM\users.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Dropbox/Programaci%C3%B3n/PI%20MLOps%20-%20STEAM/users.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> archivo_excel = "df_reviews.xlsx"
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Dropbox/Programaci%C3%B3n/PI%20MLOps%20-%20STEAM/users.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> # Leer el archivo Excel y guardarlo en una variable
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Dropbox/Programaci%C3%B3n/PI%20MLOps%20-%20STEAM/users.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> datos = pd.read_excel(archivo_excel)
#       <a href='vscode-notebook-cell:/c%3A/Users/Usuario/Dropbox/Programaci%C3%B3n/PI%20MLOps%20-%20STEAM/users.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> # Imprimir los datos leídos
# ...
